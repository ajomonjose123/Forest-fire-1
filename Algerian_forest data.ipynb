# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# importing the data
df=pd.read_csv("Algerian_forest_fires_dataset.csv")
df.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0   1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1   2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2   3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3   4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4   5     6  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes
# 0  not fire
# 1  not fire
# 2  not fire
# 3  not fire
# 4  not fire

# %%
df.describe() # there are 14 variables in the dataset
# Out:
#         day month  year Temperature   RH   Ws Rain   FFMC  DMC   DC  ISI  BUI  \
# count   246   245   245         245  245  245   245   245  245  245  245  245
# unique   33     5     2          20   63   19    40   174  167  199  107  175
# top       1     7  2012          35   64   14     0  88.9  7.9    8  1.1    3
# freq      8    62   244          29   10   43   133     8    5    5    8    5
#
#         FWI Classes
# count   245       244
# unique  127         9
# top     0.4   fire
# freq     12       131

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 247 entries, 0 to 246
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4    RH          245 non-null    object
#  5    Ws          245 non-null    object
#  6   Rain         245 non-null    object
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      244 non-null    object
# dtypes: object(14)
# memory usage: 27.1+ KB

# %%
df[df.isnull().any(axis=1)] # here we are finding variables and rows with null values
# 122 and 123 rows are null
# Out:
#                                day month  year Temperature   RH   Ws Rain   \
# 122                            NaN   NaN   NaN         NaN  NaN  NaN   NaN
# 123  Sidi-Bel Abbes Region Dataset   NaN   NaN         NaN  NaN  NaN   NaN
# 168                             14     7  2012          37   37   18   0.2
#
#      FFMC   DMC      DC   ISI   BUI      FWI Classes
# 122   NaN   NaN     NaN   NaN   NaN      NaN       NaN
# 123   NaN   NaN     NaN   NaN   NaN      NaN       NaN
# 168  88.9  12.9  14.6 9  12.5  10.4  fire          NaN

# %%
df.loc[120:130]
# Out:
#                                day  month  year  Temperature   RH   Ws  Rain   \
# 120                             29      9  2012           26   80   16    1.8
# 121                             30      9  2012           25   78   14    1.4
# 122                            NaN    NaN   NaN          NaN  NaN  NaN    NaN
# 123  Sidi-Bel Abbes Region Dataset    NaN   NaN          NaN  NaN  NaN    NaN
# 124                            day  month  year  Temperature   RH   Ws  Rain
# 125                              1      6  2012           32   71   12    0.7
# 126                              2      6  2012           30   73   13      4
# 127                              3      6  2012           29   80   14      2
# 128                              4      6  2012           30   64   14      0
# 129                              5      6  2012           32   60   14    0.2
# 130                              6      6  2012           35   54   11    0.1
#
# ...

# %%
drop_row=[122,123,124] # droping null rows and the row which contain the variable names, that is 124
df=df.drop(drop_row)

# %%
df.loc[120:130]
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 120  29     9  2012          26  80  16   1.8  47.4  2.9   7.7  0.3    3  0.1
# 121  30     9  2012          25  78  14   1.4    45  1.9   7.5  0.2  2.4  0.1
# 125   1     6  2012          32  71  12   0.7  57.1  2.5   8.2  0.6  2.8  0.2
# 126   2     6  2012          30  73  13     4  55.7  2.7   7.8  0.6  2.9  0.2
# 127   3     6  2012          29  80  14     2  48.7  2.2   7.6  0.3  2.6  0.1
# 128   4     6  2012          30  64  14     0  79.4  5.2  15.4  2.2  5.6    1
# 129   5     6  2012          32  60  14   0.2  77.1    6  17.6  1.8  6.5  0.9
# 130   6     6  2012          35  54  11   0.1  83.7  8.4  26.3  3.1  9.3  3.1
#
#        Classes
# 120  not fire
# 121  not fire
# 125  not fire
# 126  not fire
# 127  not fire
# 128  not fire
# 129  not fire
# 130      fire

# %%
df=df.dropna().reset_index(drop=True) # we are resetting index
df.loc[120:130]
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 120  29     9  2012          26  80  16   1.8  47.4  2.9   7.7  0.3     3
# 121  30     9  2012          25  78  14   1.4    45  1.9   7.5  0.2   2.4
# 122   1     6  2012          32  71  12   0.7  57.1  2.5   8.2  0.6   2.8
# 123   2     6  2012          30  73  13     4  55.7  2.7   7.8  0.6   2.9
# 124   3     6  2012          29  80  14     2  48.7  2.2   7.6  0.3   2.6
# 125   4     6  2012          30  64  14     0  79.4  5.2  15.4  2.2   5.6
# 126   5     6  2012          32  60  14   0.2  77.1    6  17.6  1.8   6.5
# 127   6     6  2012          35  54  11   0.1  83.7  8.4  26.3  3.1   9.3
# 128   7     6  2012          35  44  17   0.2  85.6  9.9  28.9  5.4  10.7
# 129   8     6  2012          28  51  17   1.3  71.4  7.7   7.4  1.5   7.3
# 130   9     6  2012          27  59  18   0.1  78.1  8.5  14.7  2.4   8.3
#
#      FWI    Classes
# 120  0.1  not fire
# 121  0.1  not fire
# ...

# %%
df.columns=df.columns.str.strip() # removing the space which occured before the variables "RH" and "Ws"
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    object
#  1   month        243 non-null    object
#  2   year         243 non-null    object
#  3   Temperature  243 non-null    object
#  4   RH           243 non-null    object
#  5   Ws           243 non-null    object
#  6   Rain         243 non-null    object
#  7   FFMC         243 non-null    object
#  8   DMC          243 non-null    object
#  9   DC           243 non-null    object
#  10  ISI          243 non-null    object
#  11  BUI          243 non-null    object
#  12  FWI          243 non-null    object
#  13  Classes      243 non-null    object
# dtypes: object(14)
# memory usage: 26.7+ KB

# %%
# changing the datatype
#here all the variables are objective, that is nothing but string. 
# string datatypes are changing to integer and float
df[["day","month","year","Temperature","RH","Ws"]]=df[["day","month","year","Temperature","RH","Ws"]].astype(int)
df[["Rain","FFMC","DMC","DC","ISI","BUI","FWI"]]=df[["Rain","FFMC","DMC","DC","ISI","BUI","FWI"]].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    int64
#  1   month        243 non-null    int64
#  2   year         243 non-null    int64
#  3   Temperature  243 non-null    int64
#  4   RH           243 non-null    int64
#  5   Ws           243 non-null    int64
#  6   Rain         243 non-null    float64
#  7   FFMC         243 non-null    float64
#  8   DMC          243 non-null    float64
#  9   DC           243 non-null    float64
#  10  ISI          243 non-null    float64
#  11  BUI          243 non-null    float64
#  12  FWI          243 non-null    float64
#  13  Classes      243 non-null    object
# dtypes: float64(7), int64(6), object(1)
# memory usage: 26.7+ KB

# %%
df.head()
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI      Classes
# 0  0.5  not fire
# 1  0.4  not fire
# 2  0.1  not fire
# 3  0.0  not fire
# 4  0.5  not fire

# %%
# plotting correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')

plt.title('Correlation Heatmap')
plt.show()
# Out:
# <ipython-input-14-3882a16500c9>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True, cmap='coolwarm')

# %%
# "DC" and "BUI" cause multicollinearity,
# removing either one of the variable
# removing "DC"
df.drop('DC', axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    int64
#  1   month        243 non-null    int64
#  2   year         243 non-null    int64
#  3   Temperature  243 non-null    int64
#  4   RH           243 non-null    int64
#  5   Ws           243 non-null    int64
#  6   Rain         243 non-null    float64
#  7   FFMC         243 non-null    float64
#  8   DMC          243 non-null    float64
#  9   ISI          243 non-null    float64
#  10  BUI          243 non-null    float64
#  11  FWI          243 non-null    float64
#  12  Classes      243 non-null    object
# dtypes: float64(6), int64(6), object(1)
# memory usage: 24.8+ KB

# %%
# droping the variable year as well, because of absence of values
df.drop('year', axis=1, inplace=True)

# %%
df.info()
df.corr()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    int64
#  1   month        243 non-null    int64
#  2   Temperature  243 non-null    int64
#  3   RH           243 non-null    int64
#  4   Ws           243 non-null    int64
#  5   Rain         243 non-null    float64
#  6   FFMC         243 non-null    float64
#  7   DMC          243 non-null    float64
#  8   ISI          243 non-null    float64
#  9   BUI          243 non-null    float64
#  10  FWI          243 non-null    float64
#  11  Classes      243 non-null    object
# dtypes: float64(6), int64(5), object(1)
# memory usage: 22.9+ KB
# ...

# %%
# the dataset describes the data of two region
# dividing the regions into 0 and 1
df.loc[:122, "Region"] = 0
df.loc[122:, "Region"] = 1
df[['Region']]=df[['Region']].astype(int)

# %%
df.isnull().sum()
# Out:
# day            0
# month          0
# Temperature    0
# RH             0
# Ws             0
# Rain           0
# FFMC           0
# DMC            0
# ISI            0
# BUI            0
# FWI            0
# Classes        0
# Region         0
# dtype: int64

# %%
# counting the values of variable "Classes"
df['Classes'].value_counts()
# Out:
# fire             131
# not fire         101
# fire               4
# fire               2
# not fire           2
# not fire           1
# not fire           1
# not fire           1
# Name: Classes, dtype: int64

# %%
# make the Classes categories into two, "fire" and "not fire"
df['Classes']=np.where(df['Classes'].str.contains('not fire'),0,1)

# %%
# box plot is used to find the outlayers
sns.boxplot(df['FWI'],color='green')
# Out:
# <Axes: >

# %%
#splitting training and testing dataset
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=42)

# %%
X_train.shape,X_test.shape
# Out:
# ((182, 12), (61, 12))

# %%
# standardising the values to equal scale
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_train_scaled=scaler.fit_transform(X_train)
X_test_scaled=scaler.transform(X_test)

# %%
# doing regression and mean absolute error
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
linreg=LinearRegression()
linreg.fit(X_train_scaled,y_train)
y_pred=linreg.predict(X_test_scaled)
mae=mean_absolute_error(y_test,y_pred)
score=r2_score(y_test,y_pred)
print("Mean absolute error", mae)
print("R2 Score", score)
# Out:
# Mean absolute error 0.49016399151631906
# R2 Score 0.9885206478647467

# %%
# here the r2 is 0.98, which means the model is a good model and the model can explain 98 percentage of variations in the dependent variable using the independent variables.
# the mean absolute difference between actual and predicted values is 0.49. which means, the model is good.
